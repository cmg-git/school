# %% [markdown]
# # Fonction de é degré

# %%
import numpy as np
import matplotlib.pyplot as plt

def second_degree(a, b, c):
    # Define a range of x values from -10 to 10 with a step of 1
    x = np.arange(-10, 11, 1)
    
    # Calculate f(x) = a*x**2 + b*x + c for each x
    f_x = a * x**2 + b * x + c

    # Calculate the discriminant Δ = b^2 - 4ac
    discriminant = b**2 - 4 * a * c
    
    # Find the roots of f(x) = 0 using the quadratic formula
    if discriminant > 0:
        root1 = (-b + np.sqrt(discriminant)) / (2 * a)
        root2 = (-b - np.sqrt(discriminant)) / (2 * a)
        print('Two real roots:')
        print('Root 1:', root1)
        print('Root 2:', root2)
    elif discriminant == 0:
        root1 = -b / (2 * a)
        print('One real root (double root):')
        print('Root:', root1)
    else:
        real_part = -b / (2 * a)
        imaginary_part = np.sqrt(-discriminant) / (2 * a)
        print('Two complex roots:')
        print('Root 1:', complex(real_part, imaginary_part))
        print('Root 2:', complex(real_part, -imaginary_part))
    
    print(f'Δ = {discriminant}')
    return x, f_x


def print_fx(x, f_x):
    # Print x and f(x) values
    for xi, fi in zip(x, f_x):
        print(f'x = {xi}, f(x) = {fi}')

def plot_fx(x, f_x):
    # Plot the function and points
    plt.plot(x, f_x, label='f(x) = {:.1f}x^2 + {:.1f}x + {:.1f}'.format(a, b, c))
    plt.plot(x, f_x, 'o', label='(x, f(x))')
    plt.axhline(0, color='red', linestyle='--', label='x-axis')
    plt.axvline(x=0, color='blue', linestyle='--', label='y-axis)')
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.title('Plot of the Quadratic Function')
    plt.legend()
    plt.grid(True)
    # Draw a vertical line at x=0 (the y-axis)
    plt.show()

# %%
# Define the coefficients a, b, and c as float values
a = 1.0
b = -3.0
c = -5.0

x, f_x = second_degree(a, b, c)
print_fx(x, f_x)
plot_fx(x, f_x)
# Out:
# Two real roots:
# Root 1: 4.192582403567252
# Root 2: -1.1925824035672519
# Δ = 29.0
# x = -10, f(x) = 125.0
# x = -9, f(x) = 103.0
# x = -8, f(x) = 83.0
# x = -7, f(x) = 65.0
# x = -6, f(x) = 49.0
# x = -5, f(x) = 35.0
# x = -4, f(x) = 23.0
# x = -3, f(x) = 13.0
# x = -2, f(x) = 5.0
# x = -1, f(x) = -1.0
# x = 0, f(x) = -5.0
# x = 1, f(x) = -7.0
# x = 2, f(x) = -7.0
# x = 3, f(x) = -5.0
# x = 4, f(x) = -1.0
# x = 5, f(x) = 5.0
# x = 6, f(x) = 13.0
# x = 7, f(x) = 23.0
# x = 8, f(x) = 35.0
# x = 9, f(x) = 49.0
# x = 10, f(x) = 65.0

# %%
# Define the coefficients a, b, and c as float values
a = -1.0
b = -3.0
c = 5.0

x, f_x = second_degree(a, b, c)
plot_fx(x, f_x)
# Out:
# Two real roots:
# Root 1: -4.192582403567252
# Root 2: 1.1925824035672519
# Δ = 29.0

# %%
# Define the coefficients a, b, and c as float values
a = 1.0
b = 2.0
c = 1.0

x, f_x = second_degree(a, b, c)
plot_fx(x, f_x)
# Out:
# One real root (double root):
# Root: -1.0
# Δ = 0.0

# %%
# Define the coefficients a, b, and c as float values
a = 1.0
b = 2.0
c = 10.0

x, f_x = second_degree(a, b, c)
plot_fx(x, f_x)
# Out:
# Two complex roots:
# Root 1: (-1+3j)
# Root 2: (-1-3j)
# Δ = -36.0
