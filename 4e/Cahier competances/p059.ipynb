# %% [markdown]
# Math 4e Cahier des compétances
#
# # Je caractérise graphiqument la proportionalité
#
# page 58 - 59

# %% [markdown]
# **2.**
#
# -----------
#
# Representer graphiqument les données du tableau :
#
# |Masse de bonbons en *g*| 100 | 200 | 500 |
# |-----------------------|-----|-----|-----|
# |Prix en *€*            |0.80 | 1.6 | 4   |

# %%
import numpy as np
import matplotlib.pyplot as plt

masse_bonbons = np.array([100, 200, 500])
prix = np.array([0.89, 1.6, 4])

fig1, ax1 = plt.subplots()
ax1.scatter(x=masse_bonbons, y=prix, marker='o', c='r', edgecolor='b')
ax1.plot(masse_bonbons, prix)
ax1.grid(True)
ax1.set_xlabel('Masse bonbons, $g$')
ax1.set_ylabel('Prix, $€$')
# Out:
# Text(0, 0.5, 'Prix, $€$')

# %% [markdown]
# **17.**
#
# -----------------
# 1. On considère le tableau suivant:
#
#
# | x | 2 | 3 | 5 | 6 |  7 |
# |---|---|---|---|---|----|
# | y | 3 |4.5|7.5| 9 |10.5|
#
# Est-ce un tableau de proportionalité ? Justifier :

# %%
x = np.array([2, 3, 5, 6, 7])
y = np.array([3, 4.5, 7.5, 9, 10.5])

print('Les proportions (les pentes) sont :', y / x)
# Out:
# Les proportions (les pentes) sont : [1.5 1.5 1.5 1.5 1.5]

# %% [markdown]
# 2. Représenter graphiquement les données de ce tableau :

# %%
fig1, ax1 = plt.subplots()
ax1.plot(x, y, linestyle='-.', marker='o', color='g')
ax1.set_xlim([0, 7.9])
ax1.set_ylim([0, 10.9])
ax1.grid(True)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
fig1, ax1 = plt.subplots()

# %%
fig1, ax1 = plt.subplots()
ax1.plot(x, y, linestyle='-.', marker='o', color='g')

# %%
fig1, ax1 = plt.subplots()
ax1.plot(x, y, linestyle='-.', marker='o', color='g')
ax1.set_xlim([0, 7.9])
ax1.set_ylim([0, 10.9])
# Out:
# (0.0, 10.9)

# %%
fig1, ax1 = plt.subplots()
ax1.plot(x, y, linestyle='-.', marker='o', color='g')
ax1.set_xlim([0, 7.9])
ax1.set_ylim([0, 10.9])
ax1.grid(True)

# %%
fig1, ax1 = plt.subplots()
ax1.plot(x, y, linestyle='-.', marker='o', color='g')
ax1.set_xlim([0, 7.9])
ax1.set_ylim([0, 10.9])
ax1.grid(True)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')
